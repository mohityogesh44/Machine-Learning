# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street  ... MiscVal MoSold YrSold SaleType SaleCondition SalePrice
# 0   1          60       RL         65.0     8450   Pave  ...       0      2   2008       WD        Normal    208500
# 1   2          20       RL         80.0     9600   Pave  ...       0      5   2007       WD        Normal    181500
# 2   3          60       RL         68.0    11250   Pave  ...       0      9   2008       WD        Normal    223500
# 3   4          70       RL         60.0     9550   Pave  ...       0      2   2006       WD       Abnorml    140000
# 4   5          60       RL         84.0    14260   Pave  ...       0     12   2008       WD        Normal    250000
#
# [5 rows x 81 columns]

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  ...       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000  1201.000000    1460.000000  1460.000000  ...   1460.000000  1460.000000  1460.000000    1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315  ...     43.489041     6.321918  2007.815753  180921.195890
# std      42.300571    24.284752    9981.264932     1.382997  ...    496.123024     2.703626     1.328095   79442.502883
# min      20.000000    21.000000    1300.000000     1.000000  ...      0.000000     1.000000  2006.000000   34900.000000
# 25%      20.000000    59.000000    7553.500000     5.000000  ...      0.000000     5.000000  2007.000000  129975.000000
# 50%      50.000000    69.000000    9478.500000     6.000000  ...      0.000000     6.000000  2008.000000  163000.000000
# 75%      70.000000    80.000000   11601.500000     7.000000  ...      0.000000     8.000000  2009.000000  214000.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
total = df.isna().sum().sort_values(ascending=False)
percent = (df.isna().sum()/df.isna().count()).sort_values(ascending=False)
missing = pd.concat([total,percent], axis = 1, keys=['Total', 'Percent'])
missing.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageType       81  0.055479
# GarageCond       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# GarageYrBlt      81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# RoofMatl          0  0.000000

# %%
df = df.drop(missing[missing['Total']>1].index.values,1)
df = df.drop(df.loc[df['Electrical'].isnull()].index)

# %%
len(df.columns)
# Out:
# 62

# %%
corr = df.corr()
plt.figure(figsize=(10,9), dpi = 300)
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
#Now we have to encode the categorical columns
cat_mask = df.dtypes=='object'
cat_cols = df.columns[cat_mask].tolist()
#All categorical columns
cat_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
encoder = LabelEncoder()

# %%
df[cat_cols] = df[cat_cols].apply(lambda x: encoder.fit_transform(x.astype(str)))

df_copy = df.copy()

df_copy = pd.get_dummies(df_copy, columns = cat_cols)

# %%
# Out:
# (1094, 220)

# %%
#Now we split the data
x_train, x_test, y_train, y_test = train_test_split(df_copy.drop('SalePrice', axis = 1), df_copy['SalePrice'], test_size = 0.25, random_state = 42)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (1094,)
# (365,)

# %%
y_train = y_train.values.reshape(-1,1)
y_test = y_test.values.reshape(-1,1)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (1094, 1)
# (365, 1)

# %%
sc_x = StandardScaler()
sc_y = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)
y_train = sc_y.fit_transform(y_train)
y_test = sc_y.transform(y_test)

# %%
model_1 = LinearRegression()
model_1.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Predictions on train data
x_pred = model_1.predict(x_train)
x_pred = x_pred.reshape(-1,1)

#Predictions on test data
y_pred = model_1.predict(x_test)
y_pred = y_pred.reshape(-1,1)

# %%
def scores(y, x):
    print(f"RMSE: {np.sqrt(mean_squared_error(y, x))}")
    print(f"MSE: {mean_squared_error(y, x)}")
    print(f"R2 Score: {r2_score(y, x)}")

# %%
print("Training Accuracy:")
scores(y_train, x_pred)
print("---------------------------------------------")
print(f"Test Accuracy:")
scores(y_test, y_pred)
# Out:
# Training Accuracy:
# RMSE: 0.28374090860755957
# MSE: 0.08050890321744346
# R2 Score: 0.9194910967825566
# ---------------------------------------------
# Test Accuracy:
# RMSE: 24965307746.600765
# MSE: 6.232665908824842e+20
# R2 Score: -5.953088132125958e+20

# %%
def regularization(model, alpha_range):
    rmse_insample = []
    rmse_outsample = []
    r2_insample = []
    r2_outsample = []
    
    for i in alpha_range:
        reg_model = model(alpha = i, normalize = True)
        reg_model.fit(x_train, y_train)
        y_pred_train = reg_model.predict(x_train)
        y_pred_train = y_pred_train.reshape(-1,1)
        y_pred_test = reg_model.predict(x_test)
        y_pred_test = y_pred_test.reshape(-1,1)
        
        rmse_insample.append(np.sqrt(mean_squared_error(y_train, y_pred_train)))
        r2_insample.append(r2_score(y_train, y_pred_train))
        
        rmse_outsample.append(np.sqrt(mean_squared_error(y_test, y_pred_test)))
        r2_outsample.append(r2_score(y_test, y_pred_test))
    
    df = pd.DataFrame()
    df['alpha'] = alpha_range
    df['rmse_insample'] = rmse_insample
    df['rmse_outsample'] = rmse_outsample
    df['r2_insample'] = r2_insample
    df['r2_outsample'] = r2_outsample
    
    return df.plot(x = 'alpha', y = ['rmse_insample','rmse_outsample'])

# %%
#Lasso Regression
alpha_range_lasso = np.arange(0.001, 0.03, 0.001)
print(regularization(Lasso, alpha_range_lasso))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Ridge Regression
alpha_range_ridge = np.arange(0.001, 2.7, 0.01)
print(regularization(Ridge, alpha_range_ridge))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
